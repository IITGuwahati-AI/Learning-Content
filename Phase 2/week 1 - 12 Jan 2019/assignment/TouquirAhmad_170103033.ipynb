# %%
import numpy as np
from matplotlib import pyplot as plt
data = np.loadtxt('data.txt',dtype=float,skiprows=1) 
for i in range(1,11):
    for j in range(1,11):
        if i is not j:
            for k in range(0,len(data)):
                if data[k,0]==2:
                    plt.scatter(data[k,i],data[k,j],color="b")
                elif data[k,0]==1:
                    plt.scatter(data[k,i],data[k,j],color="r")
            plt.xlabel(f'Feature {i}')
            plt.ylabel(f'Feature {j}')
            
            plt.show()

# %%
#The graph of feature1 vs feature2 can classify two labels perfectly.
#The red dots and the blue dots are seperated  by a curve.
for k in range(0,len(data)):
                if data[k,0]==2:
                    plt.scatter(data[k,1],data[k,2],color="b")
                elif data[k,0]==1:
                    plt.scatter(data[k,1],data[k,2],color="r")
plt.xlabel(f'Feature 1')
plt.ylabel(f'Feature 2')
plt.plot()
# Out:
# []
