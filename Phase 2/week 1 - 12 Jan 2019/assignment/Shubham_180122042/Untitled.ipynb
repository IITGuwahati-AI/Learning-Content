# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.txt",sep='\t')

# %%
df.head()
# Out:
#    Label      1         2         3         4         5         6          7  \
# 0      2  3.201  5.774701  3.429272  0.108732 -0.146594 -2.140013   8.025347
# 1      1  1.066  0.519693  5.936320  0.194729 -1.031533  0.678119  12.408875
# 2      2  1.395  6.184605  4.393927  0.236128 -0.306630 -1.152583  12.271188
# 3      1  0.062  0.106774  0.227877  0.241525 -1.734883 -2.111483  12.531931
# 4      2  1.416  7.687776  3.696551  0.416807 -0.167303 -1.977925  12.915153
#
#           8         9         10
# 0 -0.082737 -0.316598   8.970595
# 1 -0.057266  0.129536   6.406818
# 2 -0.216143  0.654902  17.425628
# 3  0.991368  0.012839   3.487370
# 4 -0.142540  0.773266  20.234659

# %%
col_1 = np.where(df.Label == 1)
col_2 = np.where(df.Label == 2)
for i in range(10):
    for j in range(10):
        if(i!=j):
            for k in col_1:
                plt.scatter(df.loc[k,str(i+1)],df.loc[k,str(j+1)],color ='red')
            for l in col_2:
                plt.scatter(df.loc[l,str(i+1)],df.loc[l,str(j+1)],color = 'blue')
            plt.ylabel(str(i+1))
            plt.xlabel(str(j+1))
            plt.show()
#That shows that 1,2 features classify it the best!!!
#It can be easily seen that the plot b/w feature 1 and 2 classify it the best hence shown!!!
