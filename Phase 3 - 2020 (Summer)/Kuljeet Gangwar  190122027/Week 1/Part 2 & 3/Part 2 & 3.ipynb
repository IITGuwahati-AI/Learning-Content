# %%
import pandas as pd

# %%
df = pd.read_csv('data.txt', delim_whitespace=True)

# %%
df
# Out:
#      Label      1         2         3          4         5         6  \
# 0        2  3.201  5.774701  3.429272   0.108732 -0.146594 -2.140013
# 1        1  1.066  0.519693  5.936320   0.194729 -1.031533  0.678119
# 2        2  1.395  6.184605  4.393927   0.236128 -0.306630 -1.152583
# 3        1  0.062  0.106774  0.227877   0.241525 -1.734883 -2.111483
# 4        2  1.416  7.687776  3.696551   0.416807 -0.167303 -1.977925
# ..     ...    ...       ...       ...        ...       ...       ...
# 994      1  1.866  2.950051  1.702322  11.655344 -1.059964 -0.484756
# 995      1  0.966  2.803543  4.665996  11.683653 -1.941229 -2.860437
# 996      1  0.854  0.977449  5.408350  11.690255  0.066929 -2.310025
# 997      1  0.030  0.093712  3.678407  11.871393 -0.085895 -0.717800
# 998      2  3.881  5.772867  0.973869  11.916999 -0.622275 -1.354238
#
#              7         8         9         10
# 0     8.025347 -0.082737 -0.316598   8.970595
# ...

# %%
df.sort_values(by='Label', inplace=True)

# %%
df['Label'].value_counts()
# Out:
# 1    500
# 2    499
# Name: Label, dtype: int64

# %%
df.columns = ['Label','a','b','c','d','e','f','g','h','i','j']

# %%
df
# Out:
#      Label      a         b         c          d         e         f  \
# 339      1  1.895  2.728391  4.927970   4.627932 -0.895528 -0.068311
# 355      1  0.169  0.388358  5.004765   4.783888 -2.259420 -0.760004
# 838      1  3.515  1.227723  2.096629   8.640174 -1.120949 -1.228596
# 839      1  2.393  2.195439  1.580588   8.649852 -0.910379 -2.718849
# 352      1  0.412  1.014778  2.218705   4.764382 -0.014806 -0.011220
# ..     ...    ...       ...       ...        ...       ...       ...
# 469      2  3.070  4.306119  5.863501   5.556953 -0.141445 -1.611366
# 470      2  1.679  5.669752  4.235840   5.558591 -0.342427 -0.566348
# 472      2  6.424  4.512833  5.659092   5.599437  0.386696 -1.315091
# 456      2  2.727  3.028663  0.108216   5.456554 -0.946672 -0.288372
# 998      2  3.881  5.772867  0.973869  11.916999 -0.622275 -1.354238
#
#              g         h         i          j
# 339  10.322427 -0.198226 -1.403988   0.601839
# ...

# %%
df1 = df.iloc[:500]
df2 = df.iloc[500:]

# %%
df1a = df1.a.tolist()

# %%
df2a = df2.a.tolist()

# %%
df2b = df2.b.tolist()
df1b = df1.b.tolist()
df1c = df1.c.tolist()
df1d = df1.d.tolist()
df1e = df1.e.tolist()
df1f = df1.f.tolist()
df1g = df1.g.tolist()
df1h = df1.h.tolist()
df1i = df1.i.tolist()
df1j = df1.j.tolist()
df2c = df2.c.tolist()
df2d = df2.d.tolist()
df2e = df2.e.tolist()
df2f = df2.f.tolist()
df2g = df2.g.tolist()
df2h = df2.h.tolist()
df2i = df2.i.tolist()
df2j = df2.j.tolist()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

# %%
style.use('fivethirtyeight')
plt.plot(df1c,df1h,'r', label='Label 1',linewidth = 1)
plt.plot(df2c,df2h,'b', label='Label 2',linewidth = 1)
plt.legend()
plt.title('feature 3 vs 8')
plt.xlabel('feature 3')
plt.ylabel('feature 8')
# Out:
# Text(0, 0.5, 'feature 8')

# %% [markdown]
# # Part 3

# %%
# On manually analysing all the plots it is found that feature 3 and feature 8 classify the labels perfectly.
